# %% [markdown]
# <h2 align="center">基于 Python 网路爬虫可视化模块</h2>
# 本系统利用 Python 等一系列软件技术，以西安建筑科技大学图书馆为爬取对象，获取当前图书馆有关书籍与借阅信息，以下为可视化模块具体内容

# %%
# init
# %matplotlib inline
from preload import *
HTML(hide_code_html)
# Out:
# <script>
#     code_show=true;
#     function code_toggle() {
#         if (code_show){
#             $('div.input').hide();
#             } else {
#                 $('div.input').show();
#                 }
#                 code_show = !code_show
#                 }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()">
#     <input type="submit" value="Toggle CODE">
# </form>

# %% [markdown]
# ### 1. 简单统计可视化
#
# 西安建筑科技大学图书馆经统计藏书量约 **38W** 种书， **185W** 本书，总爬取时间为 11 小时
#
# **22 大 cls 263 小 cls 表格说明 按照 中图法**
#
# |  类别ID  |  类别名  |
# |:----:|:----:|
# |A|马列主义, 毛泽东思想, 邓小平理论|
# |B|哲学, 宗教|
# |C|社会科学总论|
# |D|政治, 法律|
# |E|军事|
# |F|经济|
# |G|文化, 科学, 教育, 体育|
# |H|语言, 文字|
# |I|文学|
# |J|艺术|
# |K|历史, 地理|
# |N|自然科学总论|
# |O|数理科学与化学|
# |P|天文学, 地球科学|
# |Q|生物科学|
# |R|医药, 卫生|
# |S|农业科学|
# |T|工业技术|
# |U|交通运输|
# |V|航空, 航天|
# |X|环境科学, 安全科学|
# |Z|综合性图书|

# %% [markdown]
# #### 2.1. 出版量前十的出版社【横向柱状图】

# %%
draw_barh('qian10press')

# %% [markdown]
# #### 2.2. 借阅量前十的书籍【横向柱状图】

# %%
draw_barh('qian10jie')

# %% [markdown]
# #### 2.3. 馆藏地藏书量比较【饼状图】

# %%
draw_pie('qian10guan')

# %% [markdown]
# #### 2.4. 图书类别借阅量比较【饼状图】

# %%
draw_pie('qian10cls')

# %% [markdown]
# #### 2.5. 图书类别在 2011 年到 2017 年的出版占比【饼状图】

# %%
draw_pie('press2year1')

# %% [markdown]
# #### 2.6. 在 2011 年到 2017 年期间图书类别的出版占比【饼状图】

# %%
draw_pie('press2year2')

# %% [markdown]
# #### 2.7. 书籍关键字——“字云”

# %%
draw_yun('ziyun')
